# %% [markdown]
# # Exponentiation by squaring
#
# (Faster than recursion)

# %%
from IPython.display import Image
Image("/home/huynguyen/Desktop/temp/Algorithm---Data-Structure/recursion/exponentiation.png")

# %%
def expo(x, n):
    if n == 1:
        return x
    if n % 2 == 0:
        return expo(x*x, n/2)
    else:
        return x * expo(x*x, (n-1)/2)
    
expo(4,9)
# Out:
# 262144

# %% [markdown]
# ## Fast modular exponentiation
#
# https://www.khanacademy.org/computing/computer-science/cryptography/modarithmetic/a/fast-modular-exponentiation

# %%
from IPython.display import Image
Image("/home/huynguyen/Desktop/temp/Algorithm---Data-Structure/recursion/mod1.jpg")

# %%
from IPython.display import Image
Image("/home/huynguyen/Desktop/temp/Algorithm---Data-Structure/recursion/mod2.jpg")

# %%
from IPython.display import Image
Image("/home/huynguyen/Desktop/temp/Algorithm---Data-Structure/recursion/mod3.jpg")
